-- %%
-- UNDROP TABLE lakehouse.bronze.sales_commodities;

--select * from lakehouse.postgres_public.sales_commodities;
--select * from lakehouse.bronze.sales_commodities;

-- drop schema if exists lakehouse.fivetran_lightly_skiing_staging;

select * from lakehouse.gold.mostvaluableclient;

--drop table lakehouse.gold.mostvaluableclient;
